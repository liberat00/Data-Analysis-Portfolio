# %%
import pandas as pd
import numpy as np
import seaborn as sns

pd.set_option('display.max_rows', 20)

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

df = pd.read_csv(r'D:\Download\archive\movies.csv')

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#    released  score      votes         director                   writer  \
# 0      1980    8.4   927000.0  Stanley Kubrick             Stephen King
# 1      1980    5.8    65000.0   Randal Kleiser  Henry De Vere Stacpoole
# 2      1980    8.7  1200000.0   Irvin Kershner           Leigh Brackett
# 3      1980    7.7   221000.0     Jim Abrahams             Jim Abrahams
# 4      1980    7.3   108000.0     Harold Ramis       Brian Doyle-Murray
#
#              star         country      budget        gross  \
# ...

# %%
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, pct_missing * 100))

# %%
df = df.dropna()

# %%
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes         int64
# director     object
# writer       object
# star         object
# country      object
# budget        int64
# gross         int64
# company      object
# runtime     float64
# dtype: object

# %%
df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')
df['votes'] = df['votes'].astype('int64')

# %%
df['released'] = df['released'].astype(str).str.extract('([0-9]{4})').astype(int)

# %%
df.sort_values(by=['gross'], inplace=False, ascending=False)
# Out:
#                                             name     rating   genre  year  \
# 5445                                      Avatar      PG-13  Action  2009
# 7445                           Avengers: Endgame      PG-13  Action  2019
# 3045                                     Titanic      PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action  2015
# 7244                      Avengers: Infinity War      PG-13  Action  2018
# ...                                          ...        ...     ...   ...
# 5640                                 Tanner Hall          R   Drama  2009
# 2434                  Philadelphia Experiment II      PG-13  Action  1993
# 3681                                Ginger Snaps  Not Rated   Drama  2000
# 272                                     Parasite          R  Horror  1982
# 3203                                  Trojan War      PG-13  Comedy  1997
#
#       released  score      votes             director  \
# ...

# %%
df['writer'].drop_duplicates()
# Out:
# 0                  Stephen King
# 1       Henry De Vere Stacpoole
# 2                Leigh Brackett
# 3                  Jim Abrahams
# 4            Brian Doyle-Murray
#                  ...
# 7594               Abby Johnson
# 7604              Eddie Mensore
# 7616                 Andy Golub
# 7649                  Pat Casey
# 7652                    Hu Guan
# Name: writer, Length: 3205, dtype: object

# %%
df['writer'].sort_values(ascending=False)
# Out:
# 5568               Émile Zola
# 3565         Émile Gaudreault
# 6722              Àlex Pastor
# 2096                 Zoë Lund
# 6151                Zoe Kazan
#                 ...
# 2355            A.E. Hotchner
# 228     A.B. 'Banjo' Paterson
# 7370               A.A. Milne
# 2114                 A L Katz
# 1486      'Weird Al' Yankovic
# Name: writer, Length: 5421, dtype: object

# %%
# Scatter plot w/ budget vs gross

plt.scatter(x=df['budget'], y=df['gross'])
plt.title('Film Budget vs Gross')
plt.xlabel('Film Budget')
plt.ylabel('Gross Earings')
plt.show()

# %%
sns.regplot(x='budget', y='gross', data=df, line_kws={"color":"red"})
plt.show()

# %%
numeric_df = df.select_dtypes(include=['number'])
correlation = numeric_df.corr()

# %%
correlation_metrix = correlation
sns.heatmap(correlation_metrix, annot=True)
plt.title('Numeric Feature Correlation Metrix')
plt.xlabel('Movie Feature')
plt.ylabel('Movie Feature')
plt.show()

# %%
# examine correlation with non-numeric data

df_numerized = df.copy()
for col in df_numerized.columns:
    if(df_numerized[col].dtype == 'object'):
        df_numerized[col] = df_numerized[col].astype('category')
        df_numerized[col] = df_numerized[col].cat.codes

df_numerized.head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  4692       6      6  1980      1304    8.4   927000.0      1795    2832
# 1  3929       6      1  1980      1127    5.8    65000.0      1578    1158
# 2  3641       4      0  1980      1359    8.7  1200000.0       757    1818
# 3   204       4      4  1980      1127    7.7   221000.0       889    1413
# 4   732       6      4  1980      1170    7.3   108000.0       719     351
#
#    star  country      budget        gross  company  runtime
# 0   699       46  19000000.0   46998772.0     1426    146.0
# 1   214       47   4500000.0   58853106.0      452    104.0
# 2  1157       47  18000000.0  538375067.0      945    124.0
# 3  1474       47   3500000.0   83453539.0     1108     88.0
# 4   271       47   6000000.0   39846344.0     1083     98.0

# %%
correlation_metrix = df_numerized.corr()
sns.heatmap(correlation_metrix, annot=True)
plt.title('Numeric Feature Correlation Metrix')
plt.xlabel('Movie Feature')
plt.ylabel('Movie Feature')
plt.show()

# %%
df_numerized.corr()
# Out:
#               name    rating     genre      year  released     score  \
# name      1.000000 -0.029234  0.010996  0.025542 -0.006152  0.014450
# rating   -0.029234  1.000000  0.147796  0.019499  0.018083  0.065983
# genre     0.010996  0.147796  1.000000 -0.073167  0.022142  0.035106
# year      0.025542  0.019499 -0.073167  1.000000 -0.001740  0.056386
# released -0.006152  0.018083  0.022142 -0.001740  1.000000  0.045874
# score     0.014450  0.065983  0.035106  0.056386  0.045874  1.000000
# votes     0.012615  0.006031 -0.135990  0.206021  0.028833  0.474256
# director  0.015246  0.014656 -0.008553 -0.038354  0.002308  0.005413
# writer    0.012880 -0.003149  0.017578 -0.025908  0.008072  0.012843
# star     -0.006882  0.009196  0.003341 -0.032157  0.015706  0.007296
# country  -0.025490  0.008230 -0.009164 -0.066748 -0.017228 -0.043051
# budget    0.023392 -0.203946 -0.368523  0.327722  0.019952  0.072001
# gross     0.005639 -0.181906 -0.244101  0.274321  0.008501  0.222556
# ...

# %%
correlation_mat = df_numerized.corr()
corr_pairs = correlation_mat.unstack()
corr_pairs
# Out:
# name     name        1.000000
#          rating     -0.029234
#          genre       0.010996
#          year        0.025542
#          released   -0.006152
#                        ...
# runtime  country    -0.034477
#          budget      0.318695
#          gross       0.275796
#          company     0.037585
#          runtime     1.000000
# Length: 225, dtype: float64

# %%
print(df.isnull().sum())
# Out:
# name        0
# rating      0
# genre       0
# year        0
# released    0
# score       0
# votes       0
# director    0
# writer      0
# star        0
# country     0
# budget      0
# gross       0
# company     0
# runtime     0
# dtype: int64

# %%
print(corr_pairs[corr_pairs.isna()])
# Out:
# Series([], dtype: float64)

# %%
corr_sort = corr_pairs.sort_values()
corr_sort
# Out:
# budget   genre     -0.368523
# genre    budget    -0.368523
#          gross     -0.244101
# gross    genre     -0.244101
# budget   rating    -0.203946
#                       ...
# year     year       1.000000
# genre    genre      1.000000
# rating   rating     1.000000
# company  company    1.000000
# runtime  runtime    1.000000
# Length: 225, dtype: float64

# %%
high_corr = corr_sort[(corr_sort > 0.5)]
high_corr
# Out:
# votes     gross       0.614751
# gross     votes       0.614751
#           budget      0.740247
# budget    gross       0.740247
# name      name        1.000000
# director  director    1.000000
# gross     gross       1.000000
# budget    budget      1.000000
# country   country     1.000000
# star      star        1.000000
# writer    writer      1.000000
# votes     votes       1.000000
# score     score       1.000000
# released  released    1.000000
# year      year        1.000000
# genre     genre       1.000000
# rating    rating      1.000000
# company   company     1.000000
# runtime   runtime     1.000000
# dtype: float64
